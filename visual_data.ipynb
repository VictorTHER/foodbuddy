# %%
import pandas as pd

# %%
df = pd.read_csv('data_source/Ingredients_cleaned_ingredients_with_nutrients.csv')

# %%
df.tail()
# Out:
#                      ingredient         default_portion  \
# 5389  Yogurt, whole milk, plain  Quantity not specified
# 5390                      Yokan                    1 oz
# 5391                 Yuca fries  Quantity not specified
# 5392          Zucchini, pickled                   1 cup
# 5393             Zwieback toast                 1 piece
#
#       default_portion_in_grams  Calcium_(MG)_per_100G  \
# 5389                    170.00                  127.0
# 5390                     28.35                   15.0
# 5391                     70.00                   15.0
# 5392                    170.00                   15.0
# 5393                      5.00                   20.0
#
#       Carbohydrates_(G)_per_100G  Iron_(MG)_per_100G  Lipid_(G)_per_100G  \
# 5389                        5.57                0.00                4.48
# 5390                       30.63                0.59                0.24
# 5391                       34.72                0.27               13.94
# ...

# %%
new_df = df['ingredient', 'Calcium_(MG)_per_100G', 'Carbohydrates_(G)_per_100G', 'Iron_(MG)_per_100G']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/foodbuddy/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ingredient', 'Calcium_(MG)_per_100G', 'Carbohydrates_(G)_per_100G', 'Iron_(MG)_per_100G')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2 = pd.read_csv('data_source/Recipes_cleaned_recipes_with_ingredients.csv')

# %%
df2.head(20)
# Out:
#                        recipe  \
# 0             15 minute pasta
# 1             15 minute pasta
# 2             15 minute pasta
# 3             15 minute pasta
# 4             15 minute pasta
# 5             15 minute pasta
# 6             15 minute pasta
# 7             15 minute pasta
# 8             15 minute pasta
# 9   1970s-style chicken curry
# 10  1970s-style chicken curry
# 11  1970s-style chicken curry
# 12  1970s-style chicken curry
# 13  1970s-style chicken curry
# 14  1970s-style chicken curry
# 15  1970s-style chicken curry
# 16  1970s-style chicken curry
# 17  1970s-style chicken curry
# 18  1970s-style chicken curry
# 19  1970s-style chicken curry
#
#                                            ingredient  quantity  grammage  \
# 0                                         penne pasta       1.0     350.0
# 1          packs Parma ham, snipped into small pieces       2.0      80.0
# 2   small brown chestnut mushrooms, halved or quar...       1.0     250.0
# ...
