# %%
import re
import os
import ast
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from rapidfuzz import process, fuzz
from google.cloud import storage
from io import StringIO
import numpy as np
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')

from Ingredients_list_setup import download_ingredients_df
# Out:
# [nltk_data] Downloading package stopwords to /Users/pato/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/pato/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/pato/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/pato/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/pato/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def parse_ingredient(ingredient):
    """
    Input: Ingredient cell of a recipe row from the recipe dataset
    Output: A tuple (quantity, grammage, unit, name) where:
        - 'quantity': How many portions
        - 'grammage': Grammage depending on the unit provided
        - 'unit': Unit of the grammage
        - 'name': Name of the ingredient
    Purpose: Output will be used to generate a proper DataFrame using pd.DataFrame.
    """
    VALID_UNITS = {'g', 'tbsp', 'tsp', 'tspn', 'cup', 'ml', 'l', 'kg', 'oz', 'fl oz'}
    # Preprocessing to remove "/xoz" patterns and fractions like "½oz" when g is already provided
    ingredient = re.sub(r'/\d+oz', '', ingredient)  # Remove patterns like "/9oz"
    ingredient = re.sub(r'/\d+fl oz', '', ingredient)  # Remove patterns like "/9fl oz"
    ingredient = re.sub(r'/\d+[½⅓¼¾]+oz', '', ingredient)  # Remove fractions before "oz"

    # Regex to capture quantity, unit, and name
    pattern = r'(?:(\d+)(?:\s*x\s*(\d+))?)?\s*([a-zA-Z%½⅓¼]+)?\s*(.*)'
    match = re.match(pattern, ingredient)

    if match:
        quantity, sub_quantity, unit, name = match.groups()

        # Default values
        grammage = None
        portion_quantity = 1  # Default quantity if not provided

        # Handle the case of "2 x 80g"
        if sub_quantity:
            portion_quantity = int(quantity)
            grammage = int(sub_quantity)
        elif quantity and unit:
            grammage = int(quantity)
        elif quantity:
            portion_quantity = int(quantity)

        # If no grammage or unit is provided
        if not unit and not grammage:
            name = ingredient.strip()  # Full ingredient name as name

        # Debugging exception : Handling cases where the detected unit is actually the first word of the ingredient name
        if unit and unit not in VALID_UNITS:
            # Move the incorrectly detected unit back into the beggining of the name
            name = f"{unit} {name}".strip()
            unit = None  # Clear the unit, since it's invalid

        # Exception when a fraction of quantity is provided
        # Output example before fixing : 1       NaN     unit  ½ leftover roast chicken, torn into pieces
        # Fix : Check if a fraction is at the beginning of the name and adjust quantity
        fraction_pattern = r'^([½⅓¼¾])\s*(.*)'
        fraction_match = re.match(fraction_pattern, name)
        if fraction_match and portion_quantity == 1:
            fraction, remaining_name = fraction_match.groups()
            try:
                # Fraction to decimal dictionary
                fraction_value = {
                    "½": 0.5,
                    "⅓": 0.33,
                    "¼": 0.25,
                    "¾": 0.75
                }[fraction]
                portion_quantity = fraction_value  # Replacing quantity with the decimal
                name = remaining_name.strip()  # Removing the fraction from the name
            except KeyError:
                pass  # Keep running the code if error

        return (float(portion_quantity), grammage, unit, name.strip())

    # If no pattern is recognized -> Default return
    return (1, None, None, ingredient.strip())

# %%
# Step 1: Download data
client = storage.Client()
bucket_name = "recipes-dataset"
bucket = client.bucket(bucket_name)
blob = bucket.blob(f"Recipes/recipes.csv")
content = blob.download_as_text()
recipes = pd.read_csv(StringIO(content))[0:10]
recipe = recipes.copy().drop_duplicates(subset=["title"], keep='first')
print("Recipes downloaded")

ingredients = download_ingredients_df()
print("Ingredients downloaded")
# Out:
# Recipes downloaded
# Ingredients downloaded

# %%
# Step 2: Process ingredients
all_parsed_ingredients = [
    (title, *parse_ingredient(ingredient))
    for title, ingreds in zip(recipe["title"], recipe["ingredients"])
    for ingredient in ast.literal_eval(ingreds)
    ]
print("All ingredients of all recipes pulled")
all_parsed_ingredients
# Out:
# All ingredients of all recipes pulled
# [('15 minute pasta', 1.0, 350, 'g', 'penne pasta'),
#  ('15 minute pasta',
#   2.0,
#   80,
#   'g',
#   'packs Parma ham, snipped into small pieces'),
#  ('15 minute pasta',
#   1.0,
#   250,
#   'g',
#   'small brown chestnut mushrooms, halved or quartered'),
#  ('15 minute pasta', 1.0, 200, 'g', 'full-fat crème fraîche'),
#  ('15 minute pasta', 1.0, 100, 'g', 'Parmesan, grated'),
#  ('15 minute pasta', 1.0, 2, 'tbsp', 'chopped fresh parsley'),
#  ('15 minute pasta',
#   1.0,
#   None,
#   None,
#   'salt and freshly ground black pepper, to taste'),
#  ('15 minute pasta', 1.0, None, None, 'green salad'),
#  ('15 minute pasta', 1.0, None, None, 'crunchy bread'),
#  ('1970s-style chicken curry', 1.0, 30, 'g', 'unsalted butter'),
#  ('1970s-style chicken curry', 1.0, 1, None, 'onion , finely chopped'),
#  ('1970s-style chicken curry',
#   1.0,
#   1,
#   None,
#   'green eating apple, finely chopped'),
#  ('1970s-style chicken curry', 2.0, None, None, '2–3 tsp curry powder'),
#  ('1970s-style chicken curry', 1.0, 1, 'tbsp', 'plain flour'),
#  ('1970s-style chicken curry', 1.0, 350, 'ml', 'chicken stock'),
#  ('1970s-style chicken curry',
#   0.5,
#   None,
#   None,
#   'leftover roast chicken, torn into pieces'),
#  ('1970s-style chicken curry', 1.0, None, None, 'splash double cream'),
#  ('1970s-style chicken curry', 1.0, 1, None, 'squeeze lemon juice'),
#  ('1970s-style chicken curry', 1.0, 2, 'tbsp', 'sultanas'),
#  ('1970s-style chicken curry', 1.0, 2, 'tbsp', 'toasted almonds'),
#  ('1970s-style chicken curry',
#   1.0,
#   None,
#   None,
#   'salt and freshly ground black pepper'),
#  ('1970s-style chicken curry',
#   1.0,
#   None,
#   None,
#   'freshly cooked basmati rice, to serve'),
#  ('Creamy chicken pasta', 1.0, 180, 'g', 'pasta'),
#  ('Creamy chicken pasta',
#   1.0,
#   150,
#   'g',
#   'leftover roast chicken, shred into bite-sized pieces'),
#  ('Creamy chicken pasta', 1.0, 1, 'tbsp', 'plain flour'),
#  ('Creamy chicken pasta', 1.0, None, None, 'large knob of butter'),
#  ('Creamy chicken pasta',
#   1.0,
#   8,
#   None,
#   'large chestnut mushrooms, peeled and sliced'),
#  ('Creamy chicken pasta',
#   0.5,
#   None,
#   None,
#   'bunch spring onions, roughly chopped'),
#  ('Creamy chicken pasta',
#   1.0,
#   None,
#   None,
#   'generous splash dry white wine (optional)'),
#  ('Creamy chicken pasta', 0.5, 1, None, 'tbsp single cream'),
#  ('Creamy chicken pasta',
#   1.0,
#   None,
#   None,
#   'salt and freshly ground black pepper'),
#  ('Hoisin noodles', 1.0, 2, None, 'nests medium egg noodles'),
#  ('Hoisin noodles', 1.0, 1, 'tbsp', 'hoisin sauce'),
#  ('Hoisin noodles',
#   0.5,
#   1,
#   None,
#   'tbsp soy sauce, plus extra for seasoning if needed'),
#  ('Hoisin noodles', 0.5, None, None, 'tsp toasted sesame oil'),
#  ('Hoisin noodles', 1.0, 50, 'g', 'baby spinach'),
#  ('Hoisin noodles', 1.0, 2, None, 'free -range eggs'),
#  ('Hoisin noodles', 1.0, 2, None, 'large spring onions, thinly sliced'),
#  ('Hoisin noodles', 1.0, None, None, 'salt'),
#  ('Hoisin noodles',
#   1.0,
#   None,
#   None,
#   'toasted sesame seeds (optional), to garnish'),
#  ('Mixed vegetable and almond biryani', 1.0, 1, 'tbsp', 'vegetable oil'),
#  ('Mixed vegetable and almond biryani',
#   1.0,
#   1,
#   None,
#   'large onion, thinly sliced'),
#  ('Mixed vegetable and almond biryani', 1.0, 1, 'tsp', 'sea salt'),
#  ('Mixed vegetable and almond biryani',
#   1.0,
#   2,
#   None,
#   'large garlic cloves, finely chopped'),
#  ('Mixed vegetable and almond biryani', 1.0, 1, 'tsp', 'ground cumin'),
#  ('Mixed vegetable and almond biryani', 1.0, 1, 'tbsp', 'ground coriander'),
#  ('Mixed vegetable and almond biryani', 1.0, 1, 'tbsp', 'garam masala'),
#  ('Mixed vegetable and almond biryani',
#   1.0,
#   3,
#   None,
#   'green cardamom pods, lightly crushed'),
#  ('Mixed vegetable and almond biryani', 1.0, 1, None, 'vegetable stock cube'),
#  ('Mixed vegetable and almond biryani',
#   1.0,
#   300,
#   'g',
#   'mixed frozen chopped vegetables'),
#  ('Mixed vegetable and almond biryani', 1.0, 300, 'g', 'basmati rice'),
#  ('Mixed vegetable and almond biryani', 1.0, 50, 'g', 'flaked almonds'),
#  ('Mixed vegetable and almond biryani',
#   1.0,
#   None,
#   None,
#   'large handful fresh coriander, chopped'),
#  ('Mixed vegetable and almond biryani', 0.5, None, None, 'lemon, juice only'),
#  ('2-hour Christmas dinner',
#   2.0,
#   None,
#   None,
#   '2.5kg/5lb 8oz turkey crown (fully thawed if frozen)'),
#  ('2-hour Christmas dinner', 1.0, 6, None, 'rashers smoked streaky bacon'),
#  ('2-hour Christmas dinner', 1.0, None, None, 'sunflower oil, for greasing'),
#  ('2-hour Christmas dinner', 1.0, None, None, 'large knob of butter'),
#  ('2-hour Christmas dinner', 1.0, 2, None, 'medium leeks, trimmed'),
#  ('2-hour Christmas dinner', 1.0, 5, None, 'thick slices white bread'),
#  ('2-hour Christmas dinner',
#   1.0,
#   120,
#   'g',
#   'pack mixed nuts and dried fruit (I use one containing brazil nuts, pecans, almonds, sultanas and dried cranberries)'),
#  ('2-hour Christmas dinner',
#   1.0,
#   1,
#   None,
#   'small bunch fresh thyme, finely chopped'),
#  ('2-hour Christmas dinner',
#   1.0,
#   1,
#   None,
#   'large unwaxed lemon, finely grated zest only'),
#  ('2-hour Christmas dinner', 1.0, 450, 'g', '/1lb pork sausagemeat'),
#  ('2-hour Christmas dinner',
#   1.0,
#   None,
#   None,
#   'salt and freshly ground black pepper'),
#  ('2-hour Christmas dinner',
#   1.0,
#   None,
#   None,
#   '1.2kg/2lb 12oz potatoes, preferably Maris Piper or King Edward, peeled and cut into large chunks'),
#  ('2-hour Christmas dinner',
#   1.0,
#   4,
#   'tbsp',
#   'sunflower oil or melted goose fat'),
#  ('2-hour Christmas dinner',
#   8.0,
#   None,
#   None,
#   '8–12 chipolata sausages, wrapped in bacon'),
#  ('2-hour Christmas dinner',
#   1.0,
#   None,
#   None,
#   'a few sprigs fresh rosemary (optional)'),
#  ('2-hour Christmas dinner', 1.0, 2, 'tbsp', 'runny honey'),
#  ('2-hour Christmas dinner',
#   750.0,
#   None,
#   None,
#   '750–900ml/1⅓–1⅔ pint readymade chicken gravy'),
#  ('2-hour Christmas dinner',
#   1.0,
#   2,
#   None,
#   'rashers smoked streaky or back bacon, roughly chopped'),
#  ('2-hour Christmas dinner', 1.0, 4, 'tbsp', 'ruby port or red wine'),
#  ('2-hour Christmas dinner', 1.0, 2, 'tbsp', 'cranberry sauce'),
#  ('2-hour Christmas dinner', 0.5, None, None, 'tsp dried sage (optional)'),
#  ('2-hour Christmas dinner', 2.0, 40, 'g', 'packets bread sauce mix'),
#  ('2-hour Christmas dinner', 1.0, 500, 'ml', 'milk'),
#  ('2-hour Christmas dinner', 1.0, 4, 'tbsp', 'double cream'),
#  ('2-hour Christmas dinner', 1.0, 25, 'g', 'butter'),
#  ('2-hour Christmas dinner',
#   1.0,
#   None,
#   None,
#   'freshly grated nutmeg, to serve (optional)'),
#  ('2-hour Christmas dinner',
#   1.0,
#   600,
#   'g',
#   '/1lb 5oz ready-prepared carrot sticks'),
#  ('2-hour Christmas dinner',
#   1.0,
#   2,
#   'tbsp',
#   'orange juice (fresh or from a carton)'),
#  ('2-hour Christmas dinner', 1.0, None, None, 'knob of butter'),
#  ('2-hour Christmas dinner',
#   1.0,
#   2,
#   'tbsp',
#   'chopped frozen parsley or 3 tbsp freshly chopped parsley'),
#  ('2-hour Christmas dinner', 1.0, 2, None, 'good pinches caster sugar'),
#  ('2-hour Christmas dinner', 1.0, 25, 'g', 'butter'),
#  ('2-hour Christmas dinner',
#   1.0,
#   4,
#   None,
#   'rashers rindless smoked streaky bacon, cut into 2cm/¾in pieces'),
#  ('2-hour Christmas dinner',
#   1.0,
#   300,
#   'g',
#   'ready-trimmed baby Brussels sprouts, halved'),
#  ('2-hour Christmas dinner',
#   1.0,
#   200,
#   'g',
#   'cooked and peeled chestnuts, vacuum-packed or frozen and thawed, halved'),
#  ('2-hour Christmas dinner',
#   1.0,
#   None,
#   None,
#   'sea salt and freshly ground black pepper'),
#  ('3 salad dressings', 1.0, 2, 'tbsp', 'red or white wine vinegar'),
#  ('3 salad dressings', 1.0, 1, 'tsp', 'mustard, ideally Dijon or French'),
#  ('3 salad dressings', 0.5, None, None, 'garlic clove, crushed'),
#  ('3 salad dressings', 0.5, 1, None, 'tsp caster sugar'),
#  ('3 salad dressings',
#   1.0,
#   8,
#   'tbsp',
#   'extra virgin olive oil, or a mix of olive oil and sunflower oil'),
#  ('3 salad dressings',
#   1.0,
#   None,
#   None,
#   'salt and freshly ground black pepper'),
#  ('3 salad dressings', 1.0, 2, 'tbsp', 'white wine vinegar or cider vinegar'),
#  ('3 salad dressings', 1.0, 1, 'tbsp', 'wholegrain mustard'),
#  ('3 salad dressings', 1.0, 1, 'tbsp', 'runny honey'),
#  ('3 salad dressings', 1.0, 6, 'tbsp', 'sunflower or vegetable oil'),
#  ('3 salad dressings',
#   1.0,
#   None,
#   None,
#   'salt and freshly ground black pepper'),
#  ('3 salad dressings', 1.0, 6, 'tbsp', 'mayonnaise (around 75g)'),
#  ('3 salad dressings', 1.0, 2, 'tbsp', 'tomato ketchup'),
#  ('3 salad dressings', 1.0, 1, 'tsp', 'lemon juice'),
#  ('3 salad dressings', 1.0, None, None, 'splash Worcestershire sauce'),
#  ('3 salad dressings', 1.0, None, None, 'pinch cayenne pepper'),
#  ('3 stir-fry sauces', 1.0, 2, 'tbsp', 'dark soy sauce or tamari'),
#  ('3 stir-fry sauces', 1.0, 2, 'tsp', 'runny honey'),
#  ('3 stir-fry sauces', 1.0, 2, 'tsp', 'cornflour'),
#  ('3 stir-fry sauces', 1.0, 2, 'tbsp', 'tomato ketchup'),
#  ('3 stir-fry sauces', 1.0, 2, 'tsp', 'runny honey'),
#  ('3 stir-fry sauces', 1.0, 1, 'tsp', 'vinegar'),
#  ('3 stir-fry sauces', 1.0, 3, 'tbsp', 'peanut butter'),
#  ('3 stir-fry sauces', 1.0, 2, 'tbsp', 'sweet chilli dipping sauce'),
#  ('3 stir-fry sauces', 1.0, 1, 'tbsp', 'dark soy sauce or tamari'),
#  ('3D biscuits', 1.0, 200, 'g', 'unsalted soft butter'),
#  ('3D biscuits', 1.0, 200, 'g', 'caster sugar'),
#  ('3D biscuits', 1.0, 1, 'tsp', 'vanilla essence'),
#  ('3D biscuits', 1.0, 1, None, 'free -range egg, lightly beaten'),
#  ('3D biscuits', 1.0, 400, 'g', 'plain flour, plus extra for dusting'),
#  ('3D biscuits', 1.0, 1, None, 'free -range egg white'),
#  ('3D biscuits', 1.0, 250, 'g', 'icing sugar'),
#  ('3D biscuits', 1.0, None, None, 'food colouring, if using'),
#  ('3D biscuits',
#   1.0,
#   None,
#   None,
#   'ready -to-roll icing, in colours of your choice, to decorate the biscuits'),
#  ('Lemon curd ice cream', 1.0, 290, 'ml', '/½ pint double cream'),
#  ('Lemon curd ice cream', 1.0, 1, None, 'jar (340g) lemon curd'),
#  ('Lemon curd ice cream', 0.5, None, None, 'lemon, juice and zest')]

# %%
# Convert to DataFrame directly
flat_recipes_df = pd.DataFrame(
    all_parsed_ingredients,
    columns=["recipe", "quantity", "grammage", "unit", "ingredient"]
    )
print("Parsed ingredients combined into a DataFrame")
flat_recipes_df
# Out:
# Parsed ingredients combined into a DataFrame
#                    recipe  quantity  grammage  unit  \
# 0         15 minute pasta       1.0     350.0     g
# 1         15 minute pasta       2.0      80.0     g
# 2         15 minute pasta       1.0     250.0     g
# 3         15 minute pasta       1.0     200.0     g
# 4         15 minute pasta       1.0     100.0     g
# ..                    ...       ...       ...   ...
# 122           3D biscuits       1.0       NaN  None
# 123           3D biscuits       1.0       NaN  None
# 124  Lemon curd ice cream       1.0     290.0    ml
# 125  Lemon curd ice cream       1.0       1.0  None
# 126  Lemon curd ice cream       0.5       NaN  None
#
#                                             ingredient
# 0                                          penne pasta
# 1           packs Parma ham, snipped into small pieces
# 2    small brown chestnut mushrooms, halved or quar...
# 3                               full-fat crème fraîche
# 4                                     Parmesan, grated
# ..                                                 ...
# 122                           food colouring, if using
# 123  ready -to-roll icing, in colours of your choic...
# 124                               /½ pint double cream
# 125                              jar (340g) lemon curd
# 126                              lemon, juice and zest
#
# [127 rows x 5 columns]
